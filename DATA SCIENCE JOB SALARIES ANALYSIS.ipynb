# %% [markdown]
# # DATA SCIENCE JOB SALARIES ANALYSIS
# BY: PRINCESS IGE
#
# FOR: 10ALYTICS INTERNSHIP

# %% [markdown]
# ### PROJECT DESCRIPTION
#
# The aim of this project is to carry out an Exploratory Data Analysis of every feature in the dataset and understand the factors surrounding Data science Job salaries.
#
# The Jupyter notebook and oython libraries will be used for data manipulation and visualization.

# %%
#import python libraries for data manipulation and visualization

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import random

# %% [markdown]
# ### DATA INSPECTION

# %%
data_sci_salaries = pd.read_csv('ds_salaries.csv')

# %%
data_sci_salaries.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
data_sci_salaries.tail()
# Out:
#      Unnamed: 0  work_year experience_level employment_type      job_title  \
# 602         602       2022               SE              FT  Data Engineer
# 603         603       2022               SE              FT  Data Engineer
# 604         604       2022               SE              FT   Data Analyst
# 605         605       2022               SE              FT   Data Analyst
# 606         606       2022               MI              FT   AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# ...

# %% [markdown]
# ### FEATURES DESCRIPTION
# ###### Work_year - The year the salary was paid.
# ###### Experience level - The experience level in the job during the year with the following possible values: EN - Entry-level / Junior MI Mid-level / Intermediate SE - Senior-level / Expert EX - Executive-level / Director
# ###### Emploment type - The type of employement for the role: PT - Part-time FT - Full-time CT - Contract FL - Freelance
# ###### Job title - The role worked in during the year.
# ###### Salary - The total gross salary amount paid.
# ###### Salary in USD - The total gross salary amount paid in USD
# ###### Salary Currency - The currency of the salary paid as an ISO 4217 currency code.
# ###### Employee Residence - Employee's primary country of residence in during the work year as an ISO 3166 country code.
# ###### Remote ratio - The overall amount of work done remotely, possible values are as follows: 0 No remote work (less than 20%) 50 Partially remote 100 Fully remote (more than 80%)
# ###### Company Location - The country of the employer's main office or contracting branch as an ISO 3166 country code.
# ###### Company Size - The average number of people that worked for the company during the year: S - less than 50 employees (small) M - 50 to 250 employees (medium) L - more than 250 employees (large)

# %%
data_sci_salaries.shape
# Out:
# (607, 12)

# %%
data_sci_salaries.size
# Out:
# 7284

# %%
data_sci_salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
data_sci_salaries.describe().T
# Out:
#                count           mean           std     min      25%       50%  \
# Unnamed: 0     607.0     303.000000  1.753701e+02     0.0    151.5     303.0
# work_year      607.0    2021.405272  6.921330e-01  2020.0   2021.0    2022.0
# salary         607.0  324000.062603  1.544357e+06  4000.0  70000.0  115000.0
# salary_in_usd  607.0  112297.869852  7.095726e+04  2859.0  62726.0  101570.0
# remote_ratio   607.0      70.922570  4.070913e+01     0.0     50.0     100.0
#
#                     75%         max
# Unnamed: 0        454.5       606.0
# work_year        2022.0      2022.0
# salary         165000.0  30400000.0
# salary_in_usd  150000.0    600000.0
# remote_ratio      100.0       100.0

# %% [markdown]
# ### INSPECTION RESULT
#
# - The dataset was gotten from 10Alytics.
#
# - There are 607 rows and 12 columns.
#
# - There are no null values

# %%
data_sci_salaries.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
Job_title = data_sci_salaries ['job_title'] 
unique_job_title = set(Job_title)
len(unique_job_title)
# Out:
# 50

# %% [markdown]
# ### DATA CLEANING
# - Edit column names for easy readability
# - Delete unecessary columns: the first column(unnamed)

# %%
data_sci_salaries.rename(columns = {'work_year':'Work_year', 'experience_level':'Level_of_experience',
                              'employment_type':'Type_of_employment', 'job_title':'Job_title', 'salary':'Salary', 'salary_currency':'Salary_currency', 'salary_in_usd':'Salary_in_USD', 'employee_residence':'Employee_residence', 'remote_ratio':'Remote_ratio', 'company_location':'Company_location', 'company_size':'Company_size'}, inplace = True)

# %%
data_sci_salaries.head()
# Out:
#    Unnamed: 0  Work_year Level_of_experience Type_of_employment  \
# 0           0       2020                  MI                 FT
# 1           1       2020                  SE                 FT
# 2           2       2020                  SE                 FT
# 3           3       2020                  MI                 FT
# 4           4       2020                  SE                 FT
#
#                     Job_title  Salary Salary_currency  Salary_in_USD  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   Employee_residence  Remote_ratio Company_location Company_size
# 0                 DE             0               DE            L
# ...

# %%
data_sci_salaries.dtypes
# Out:
# Unnamed: 0              int64
# Work_year               int64
# Level_of_experience    object
# Type_of_employment     object
# Job_title              object
# Salary                  int64
# Salary_currency        object
# Salary_in_USD           int64
# Employee_residence     object
# Remote_ratio            int64
# Company_location       object
# Company_size           object
# dtype: object

# %%
data_sci_salaries.drop(data_sci_salaries.filter(regex="Unnamed"),axis=1, inplace=True)

# %%
data_sci_salaries.head()
# Out:
#    Work_year Level_of_experience Type_of_employment  \
# 0       2020                  MI                 FT
# 1       2020                  SE                 FT
# 2       2020                  SE                 FT
# 3       2020                  MI                 FT
# 4       2020                  SE                 FT
#
#                     Job_title  Salary Salary_currency  Salary_in_USD  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   Employee_residence  Remote_ratio Company_location Company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %% [markdown]
# ## INSIGHTS

# %% [markdown]
# ### 1. What is the most occurring company location?

# %%
data_sci_salaries['Company_location'].value_counts()
# Out:
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# LU      3
# PK      3
# BR      3
# AE      3
# MX      3
# AU      3
# TR      3
# DK      3
# IT      2
# CZ      2
# SI      2
# RU      2
# CH      2
# NG      2
# CN      2
# BE      2
# VN      1
# EE      1
# AS      1
# DZ      1
# MY      1
# MD      1
# KE      1
# SG      1
# CO      1
# IR      1
# CL      1
# MT      1
# IL      1
# UA      1
# IQ      1
# RO      1
# HR      1
# NZ      1
# HU      1
# HN      1
# IE      1
# Name: Company_location, dtype: int64

# %% [markdown]
# The most occurring company location is US; United States

# %% [markdown]
# ### 2. What is the most occurring level of experience?

# %%
data_sci_salaries['Level_of_experience'].value_counts()
# Out:
# SE    280
# MI    213
# EN     88
# EX     26
# Name: Level_of_experience, dtype: int64

# %% [markdown]
# The most occurring level of experience is SE: Senior level Expert.

# %% [markdown]
# ### 3. What is the most occurring job title?

# %%
data_sci_salaries['Job_title'].value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %% [markdown]
# The most occurring job title is Data Scientist

# %% [markdown]
# ### 4. What is the most occurring type of employment?

# %%
data_sci_salaries['Type_of_employment'].value_counts()
# Out:
# FT    588
# PT     10
# CT      5
# FL      4
# Name: Type_of_employment, dtype: int64

# %% [markdown]
# The most occurring type of employment is full-time.

# %% [markdown]
# ### 5. What is the most occuring employee residence?

# %%
data_sci_salaries['Employee_residence'].value_counts()
# Out:
# US    332
# GB     44
# IN     30
# CA     29
# DE     25
# FR     18
# ES     15
# GR     13
# JP      7
# PT      6
# BR      6
# PK      6
# NL      5
# PL      4
# IT      4
# RU      4
# AE      3
# AT      3
# VN      3
# TR      3
# AU      3
# RO      2
# BE      2
# SG      2
# SI      2
# DK      2
# HU      2
# NG      2
# MX      2
# BO      1
# MY      1
# TN      1
# IE      1
# DZ      1
# AR      1
# CZ      1
# JE      1
# LU      1
# PR      1
# RS      1
# EE      1
# CL      1
# HK      1
# KE      1
# MD      1
# CO      1
# IR      1
# CN      1
# MT      1
# UA      1
# IQ      1
# HN      1
# BG      1
# HR      1
# PH      1
# NZ      1
# CH      1
# Name: Employee_residence, dtype: int64

# %% [markdown]
# This shows that United States is the most occurring employee residence

# %% [markdown]
# ### 6. In what currency are salaries mostly paid?

# %%
data_sci_salaries['Salary_currency'].value_counts()
# Out:
# USD    398
# EUR     95
# GBP     44
# INR     27
# CAD     18
# JPY      3
# PLN      3
# TRY      3
# CNY      2
# MXN      2
# HUF      2
# DKK      2
# SGD      2
# BRL      2
# AUD      2
# CLP      1
# CHF      1
# Name: Salary_currency, dtype: int64

# %% [markdown]
# Salaries are mostly paid in USD.

# %% [markdown]
# ### 7. What is the most common company size?

# %%
data_sci_salaries['Company_size'].value_counts()
# Out:
# M    326
# L    198
# S     83
# Name: Company_size, dtype: int64

# %% [markdown]
# Medium sized companies are the most common

# %%
data_sci_salaries.head()
# Out:
#    Work_year Level_of_experience Type_of_employment  \
# 0       2020                  MI                 FT
# 1       2020                  SE                 FT
# 2       2020                  SE                 FT
# 3       2020                  MI                 FT
# 4       2020                  SE                 FT
#
#                     Job_title  Salary Salary_currency  Salary_in_USD  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   Employee_residence  Remote_ratio Company_location Company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %% [markdown]
# ### DATA VISUALIZATION
#
#
# ### Univariate Analysis

# %%
data_sci_salaries.head()
# Out:
#    Work_year Level_of_experience Type_of_employment  \
# 0       2020                  MI                 FT
# 1       2020                  SE                 FT
# 2       2020                  SE                 FT
# 3       2020                  MI                 FT
# 4       2020                  SE                 FT
#
#                     Job_title  Salary Salary_currency  Salary_in_USD  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   Employee_residence  Remote_ratio Company_location Company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
#visualization of various columns

fig, axes = plt.subplots(2,3, figsize = (20,10))
sns.countplot(x='Work_year', data=data_sci_salaries, ax= axes[0,0])
sns.countplot(x='Type_of_employment',data=data_sci_salaries, ax= axes[0,1])
sns.countplot(y='Salary_currency',data=data_sci_salaries, ax= axes[0,2])
sns.countplot(y='Remote_ratio', data=data_sci_salaries, ax= axes[1,0])
sns.countplot(x='Company_size', data=data_sci_salaries, ax= axes[1,1])
sns.countplot(x='Level_of_experience', data=data_sci_salaries, ax= axes[1,2])
# Out:
# <AxesSubplot:xlabel='Level_of_experience', ylabel='count'>

# %%
#visualization of salary in USD

sns.boxplot(y='Salary_in_USD',data=data_sci_salaries)
plt.show()

# %% [markdown]
# The highest of amount of salary paid in USD is $600,000 and it is an outlier

# %%
# visualize job title

plt.figure(figsize=(10,20))

sns.countplot(y='Job_title', data=data_sci_salaries)
plt.title('Job titles')
plt.xlabel('Count of Job titles', weight='bold', fontsize=15)
plt.ylabel('Job titles')
# Out:
# Text(0, 0.5, 'Job titles')

# %% [markdown]
# This shows that the job title: Data scientist is the highest occurring job followed by Data engineer and Data analyst

# %%
# visualize Employee residence

plt.figure(figsize=(10,20))

sns.countplot(y='Employee_residence', data=data_sci_salaries)
plt.title('Employee residence')
plt.xlabel('Count of employee residence')
plt.ylabel('employee residence')
# Out:
# Text(0, 0.5, 'employee residence')

# %% [markdown]
# The most common employee residence is United States(US)

# %%
# visualize company location 

plt.figure(figsize=(10,20))

sns.countplot(y='Company_location', data=data_sci_salaries)
plt.title('Company_location')
plt.xlabel('Count of Company location', weight='bold', fontsize=15)
plt.ylabel('Company location')
# Out:
# Text(0, 0.5, 'Company location')

# %% [markdown]
# The highest occurring company location is United States (US)

# %% [markdown]
# ### Bivariate Analysis

# %%
#visualize remote ratio by work year

plt.figure(figsize=(10,5))
plt.title("Remote ratio vs Work year", weight='bold', fontsize=15)
sns.countplot(x='Work_year', data=data_sci_salaries, hue='Remote_ratio')
plt.xlabel('Work year')
# Out:
# Text(0.5, 0, 'Work year')

# %% [markdown]
# During each year, more work was done remotely but this shows that the amount of work done remotely in 2022 was the highest.

# %%
#visualize type of employment vs level of experience

plt.figure(figsize=(15,5))
plt.title('Type of employment vs Level of experience', weight='bold', fontsize=15)
sns.countplot(x='Type_of_employment', data=data_sci_salaries, hue='Level_of_experience')
plt.xlabel('Type of employment')
# Out:
# Text(0.5, 0, 'Type of employment')

# %% [markdown]
# This shows that employees with full-time jobs have the highest level of experience

# %%
#visualize company size vs level of experience

plt.figure(figsize=(10,5))
plt.title("Company size vs level of experience")
sns.countplot(x='Company_size', data=data_sci_salaries ,hue='Level_of_experience')
plt.xlabel('Company_size')
# Out:
# Text(0.5, 0, 'Company_size')

# %% [markdown]
# From this, it is seen that the highest level of experience in large companies is MI-Midlevel/Intermediate and the lowest is EX-Executive level/Director. In small companies, the highest levels of experience are MI-Midlevel/Intermediate and EN- Entry level/Junior. In medium-sized companies, the highest level of experience possessed by their staff is SE- Senior level/Expert while the lowest level of experience is EX-Executive level/Director. Overall, the staff of medium-sized companies have the highest level of experience or it could be said that medium-sized companies have most of their staff in Senior level/Expert roles.

# %%
#visualize company location vs level of experience

plt.figure(figsize=(25,10))
plt.title("Company location vs level of experience", weight='bold', fontsize=15)
sns.countplot(x='Company_location', data=data_sci_salaries ,hue='Level_of_experience')
plt.xlabel('Company_location')
# Out:
# Text(0.5, 0, 'Company_location')

# %% [markdown]
# Companies in the US- United States have staffers with the highest levels of experience and the SE-Senior level/Expert roles are the most common.

# %%
#visualize employee residence vs level of experience

plt.figure(figsize=(25,10))
plt.title("Employee residence vs level of experience")
sns.countplot(x='Employee_residence', data=data_sci_salaries ,hue='Level_of_experience')
plt.xlabel('Employee residence')
# Out:
# Text(0.5, 0, 'Employee residence')

# %% [markdown]
# Employees in the US-United States have the highest levels of experience and the most common role among them is the SE-Senior level/Expert roles

# %%
#visualize salary vs work year

fig, ax1 = plt.subplots(figsize = (8,8))
plt.ticklabel_format(style='plain')
plt.title('Salary vs Work year ', weight='bold', fontsize=15)
viz = sns.barplot(ax =ax1, x = 'Work_year', y= 'Salary', data = data_sci_salaries)

# %% [markdown]
# The highest amount of salaries were paid in 2021

# %%
#visualize Salary in USD vs work year

fig, ax1 = plt.subplots(figsize = (8,8))
sns.barplot(x='Work_year', y='Salary_in_USD',data=data_sci_salaries)
plt.title('Salary in USD vs Work year ', weight='bold', fontsize=15)
plt.show()

# %% [markdown]
# The highest salaries in USD - United State Dollars were paid in 2022

# %%
#visualize Salary vs Level of experience

data_sci_salaries.Salary = data_sci_salaries.Salary.astype(float)
salary_list = list(data_sci_salaries['Level_of_experience'].unique())
salary_ratio = []
for i in salary_list:
    x = data_sci_salaries[data_sci_salaries['Level_of_experience']==i]
    salary_rate = sum(x.Salary)/len(x)
    salary_ratio.append(salary_rate)
df1 = pd.DataFrame({'salary_list':salary_list,'salary_ratio':salary_ratio})
new_index = (df1['salary_ratio'].sort_values(ascending=False)).index.values
sorted_data = df1.reindex(new_index)

# showing visualization
plt .figure(figsize=(10,5))
sns.barplot(x=sorted_data['salary_list'], y=sorted_data['salary_ratio'])
plt.xticks(rotation= 90)
plt.xlabel('Experience Level')
plt.ylabel('Salary')
plt.title('Salary vs Level of experience', weight='bold', fontsize=15)
plt.show()

# %% [markdown]
# Staffers in MI-Midlevel/Intermediate roles were paid the highest salaries in various currencies

# %%
#visualize Salary_in_USD vs Level of experience

data_sci_salaries.Salary_in_USD = data_sci_salaries.Salary_in_USD.astype(float)
salary_list = list(data_sci_salaries['Level_of_experience'].unique())
salary_ratio = []
for i in salary_list:
    x = data_sci_salaries[data_sci_salaries['Level_of_experience']==i]
    salary_rate = sum(x.Salary_in_USD)/len(x)
    salary_ratio.append(salary_rate)
df1 = pd.DataFrame({'salary_list':salary_list,'salary_ratio':salary_ratio})
new_index = (df1['salary_ratio'].sort_values(ascending=False)).index.values
sorted_data = df1.reindex(new_index)

# showing visualization
plt .figure(figsize=(10,5))
sns.barplot(x=sorted_data['salary_list'], y=sorted_data['salary_ratio'])
plt.xticks(rotation= 90)
plt.xlabel('Experience Level')
plt.ylabel('Salary_in_USD')
plt.title('Salary in USD vs Level of experience', weight='bold', fontsize=15)
plt.show()

# %% [markdown]
# Staffers in EX- Executive level/Director roles were paid the highest salaries in USD

# %%
#visualize salary vs Company size

fig, ax1 = plt.subplots(figsize = (8,8))
plt.ticklabel_format(style='plain')
plt.title('Salary vs Company size ', weight='bold', fontsize=15)
viz = sns.barplot(ax =ax1, x = 'Company_size', y= 'Salary', data = data_sci_salaries)

# %% [markdown]
# Large companies pay the highest salaries while medium companies pay the least salaries

# %%
#visualize work year vs remote ratio

fig, ax1 = plt.subplots(figsize = (8,8))
sns.barplot(x='Work_year', y='Remote_ratio',data=data_sci_salaries)
plt.title('Work year by Remote ratio', weight='bold', fontsize=15)
plt.show()

# %% [markdown]
# A high amount of work was done remotely each year but more work was done remotely in 2022

# %%
#visualize Salary vs Type of employment

fig, ax1 = plt.subplots(figsize = (8,8))
sns.barplot(x='Type_of_employment', y='Salary',data=data_sci_salaries)
plt.title('Salary vs Type of employment', weight='bold', fontsize=15)
plt.show()

# %% [markdown]
# More salaries were paid to FT- full time staff and the least salaries were paid to FL- Freelancers

# %%
#visualize Type of employment vs remote ratio

fig, ax1 = plt.subplots(figsize = (8,8))
sns.barplot(x='Type_of_employment', y='Remote_ratio',data=data_sci_salaries)
plt.title('Type of employment vs Remote ratio', weight='bold', fontsize=15)
plt.show()

# %% [markdown]
# This shows that more remote work was carried out by CL- Contract staff and the least amount of remote work was carried out by FL- Freelancers

# %%
# visualize salary vs job title

data_sci_salaries.Salary = data_sci_salaries.Salary.astype(float)
salary_list = list(data_sci_salaries['Job_title'].unique())
salary_ratio = []
for i in salary_list:
    x = data_sci_salaries[data_sci_salaries['Job_title']==i]
    salary_rate = sum(x.Salary)/len(x)
    salary_ratio.append(salary_rate)
df1 = pd.DataFrame({'salary_list':salary_list,'salary_ratio':salary_ratio})
new_index = (df1['salary_ratio'].sort_values(ascending=False)).index.values
sorted_data = df1.reindex(new_index)

#visualization
plt.figure(figsize=(20,15))
sns.barplot(x=sorted_data['salary_list'], y=sorted_data['salary_ratio'])
plt.xticks(rotation= 90)
plt.xlabel('Job_title')
plt.ylabel('Salary')
plt.title('Salary by Job Title', weight='bold', fontsize=15)
plt.show()

# %% [markdown]
# Head of Machine Learning, ML Engineer, BI Data Analyst, Lead Data Scientist, Data Science Manager, Lead Data Analyst, Data Scientist, Big Data Engineer, Data Analytics Lead and 3D Computer Vision Researcher were the highest paid roles when salaries were paid in various currencies

# %%
# visualize salary in USD vs job title

data_sci_salaries.Salary_in_USD = data_sci_salaries.Salary_in_USD.astype(float)
salary_list = list(data_sci_salaries['Job_title'].unique())
salary_ratio = []
for i in salary_list:
    x = data_sci_salaries[data_sci_salaries['Job_title']==i]
    salary_rate = sum(x.Salary_in_USD)/len(x)
    salary_ratio.append(salary_rate)
df1 = pd.DataFrame({'salary_list':salary_list,'salary_ratio':salary_ratio})
new_index = (df1['salary_ratio'].sort_values(ascending=False)).index.values
sorted_data = df1.reindex(new_index)

#visualization
plt.figure(figsize=(20,15))
sns.barplot(x=sorted_data['salary_list'], y=sorted_data['salary_ratio'])
plt.xticks(rotation= 90)
plt.xlabel('Job_title')
plt.ylabel('Salary_in_USD')
plt.title('Top 10 highest paid Data roles', weight='bold', fontsize=15)
plt.show()

# %% [markdown]
# The Data Analytics Lead, Principal Data Engineer, Financial Data Analyst, Principal Data Scientist, Director of Data Science, Data Archiect, Applied Data Scientist, Analytics Engineer, Data Specialist and Head of Data are the top 10 highest paid roles when salaries are paid in USD

# %%
# visualize salary vs company location

data_sci_salaries.Salary = data_sci_salaries.Salary.astype(float)
salary_list = list(data_sci_salaries['Company_location'].unique())
salary_ratio = []
for i in salary_list:
    x = data_sci_salaries[data_sci_salaries['Company_location']==i]
    salary_rate = sum(x.Salary)/len(x)
    salary_ratio.append(salary_rate)
df1 = pd.DataFrame({'salary_list':salary_list,'salary_ratio':salary_ratio})
new_index = (df1['salary_ratio'].sort_values(ascending=False)).index.values
sorted_data = df1.reindex(new_index)

#visualization
plt.figure(figsize=(20,15))
sns.barplot(x=sorted_data['salary_list'], y=sorted_data['salary_ratio'])
plt.xticks(rotation= 90)
plt.xlabel('Company_location')
plt.ylabel('Salary')
plt.title('Salary vs Company location', weight='bold', fontsize=15)
plt.show()

# %%
data_sci_salaries.head()
# Out:
#    Work_year Level_of_experience Type_of_employment  \
# 0       2020                  MI                 FT
# 1       2020                  SE                 FT
# 2       2020                  SE                 FT
# 3       2020                  MI                 FT
# 4       2020                  SE                 FT
#
#                     Job_title    Salary Salary_currency  Salary_in_USD  \
# 0              Data Scientist   70000.0             EUR        79833.0
# 1  Machine Learning Scientist  260000.0             USD       260000.0
# 2           Big Data Engineer   85000.0             GBP       109024.0
# 3        Product Data Analyst   20000.0             USD        20000.0
# 4   Machine Learning Engineer  150000.0             USD       150000.0
#
#   Employee_residence  Remote_ratio Company_location Company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %% [markdown]
# ### Multivariate analysis

# %%
data_sci_salaries.corr()
# Out:
#                Work_year    Salary  Salary_in_USD  Remote_ratio
# Work_year       1.000000 -0.087577       0.170493      0.076314
# Salary         -0.087577  1.000000      -0.083906     -0.014608
# Salary_in_USD   0.170493 -0.083906       1.000000      0.132122
# Remote_ratio    0.076314 -0.014608       0.132122      1.000000

# %%
#Correlation plot between Work year, Salary, Salary in USD and  Remote ratio

Corr = data_sci_salaries.corr()
fig, ax = plt.subplots(figsize=(10,8)) 
sns.heatmap(Corr, annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The correlation that exist between Work year, Salary, Salary in USD and  Remote ratio is either low negative or low positive correlation.
#
# Hence, there is no strong correlation between Work year, Salary, Salary in USD and  Remote ratio

# %%
plt.figure(figsize=(20,15))
data_sci_salaries.groupby('Company_location').mean().plot(kind='bar',figsize=(20,5))
plt.title('Mean count with regards to Salary', weight='bold').set_fontsize('16')

# %% [markdown]
# ### Summary
# - The US- United States is the most juicy location for Data science roles because employees and companies in the US have the highest levels of experience in Data roles. Also, salaries in USD are on the rise as it was shown in our visualization that the highest salaries in USD were paid in 2022 and it has consistetly been on the rise since 2020.
# - For Data roles, the higher the level of experience, the higher the salary most especially, when the salary is paid in USD.
# - Large companies pay the highest salaries to staffers in data science roles.
# - The top 10 data roles according to our dataset inculude: Data scientist, Machine Learning Scientist, Big Data Engineer, Product Data Analyst, Machine Learning Engineer, Data Analyst and Lead Data Analyst.

# %% [markdown]
# ### Action points
# - More people should be encouraged to transition to Data science roles and work towards climbing the career ladder to become expert in their roles.
# - People should specialise more in these roles: Data scientist, Machine Learning Scientist, Big Data Engineer, Product Data Analyst, Machine Learning Engineer, Data Analyst and Lead Data Analyst.
